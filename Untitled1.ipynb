# %% [markdown]
# <a href="https://colab.research.google.com/github/alheekmahlib/zad_ai/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text
# !pip uninstall -y nvidia-nvjitlink-cu12 nvidia-nccl-cu12 nvidia-curand-cu12 nvidia-cufft-cu12 nvidia-cuda-runtime-cu12 nvidia-cuda-nvrtc-cu12 nvidia-cuda-cupti-cu12 nvidia-cublas-cu12 nvidia-cusparse-cu12 nvidia-cudnn-cu12 nvidia-cusolver-cu12
# !pip install transformers torch datasets accelerate
# Out:
# Found existing installation: nvidia-nvjitlink-cu12 12.4.127
# Uninstalling nvidia-nvjitlink-cu12-12.4.127:
#   Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127
# Found existing installation: nvidia-nccl-cu12 2.21.5
# Uninstalling nvidia-nccl-cu12-2.21.5:
#   Successfully uninstalled nvidia-nccl-cu12-2.21.5
# Found existing installation: nvidia-curand-cu12 10.3.5.147
# Uninstalling nvidia-curand-cu12-10.3.5.147:
#   Successfully uninstalled nvidia-curand-cu12-10.3.5.147
# Found existing installation: nvidia-cufft-cu12 11.2.1.3
# Uninstalling nvidia-cufft-cu12-11.2.1.3:
#   Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
# Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
# Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#   Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
# Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
# Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#   Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
# ...

# %%
# !python fine_tune_qa_model.py
# Out:
# 2025-08-07 01:54:00.977217: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754531641.348735   17441 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754531641.455587   17441 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1754531642.255966   17441 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
